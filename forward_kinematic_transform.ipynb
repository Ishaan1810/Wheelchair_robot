# %%
import sympy as sy
import numpy as n
from sympy import symbols,diff,sin,cos,tan,sec
from sympy.matrices import Matrix
from functools import partial
import math as m
roundup=partial(round,ndigits=4)
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D


# Defining all the required symbols
d1,d2,d3,d4,d5,d6,d7,theta1,theta2,theta3,theta4,theta5,theta6,theta7,r1,r2,r3,r4,r5,r6,r7,alpha1,alpha2,alpha3,alpha4,alpha5,alpha6,alpha7 = symbols ('d1 d2 d3 d4 d5 d6 d7 theta1 theta2 theta3 theta4 theta5 theta6 theta7 r1 r2 r3 r4 r5 r6 r7 alpha1 alpha2 alpha3 alpha4 alpha5 alpha6 alpha7 ')

#defining d values(mm)
# d1=114.3
# d2=102.616
# d3=77.216
# d4=0
# d5=127
# d6=0
# d7=50.8
# d8=0
# d9=-128
# d10=-76.2
# d11=-51.8
# d12=-153.42
# d13=77.19
# d14=-133.5
# d15=0

#defining alpha values(degrees)
# alpha1=-m.pi/2
# alpha2=m.pi/2
# alpha3=0
# alpha4=0
# alpha5=0
# alpha6=-m.pi/2
# alpha7=-m.pi/2
# alpha8=0
# alpha9=0
# alpha10=-m.pi/2
# alpha11=0
# alpha12=m.pi/2
# alpha13=m.pi
# alpha14=0
# alpha15=m.pi


#defining r values(mm)
# r1=0
# r2=0
# r3=0
# r4=51.8
# r5=0
# r6=101.6
# r7=0
# r8=-101.6
# r9=0
# r10=0
# r11=0
# r12=0
# r13=102.55
# r14=0
# r15=66.3

#defining theta values(degrees)(the final position of the end effector can be found out just by editing the values of theta below)
# theta1=0
# theta2=0
# theta3=0
# theta4=m.pi/2
# theta5=-m.pi/2
# theta6=0
# theta7=0
# theta8=0
# theta9=0
# theta10=0
# theta11=0
# theta12=0
# theta13=0
# theta14=0
# theta15=m.pi/2

# %%
#Printing the Required Matrices from the D-H parameter table
T1 = sy.Matrix([[sy.cos(theta1),-sy.sin(theta1)*sy.cos(-m.pi/2),sy.sin(theta1)*sy.sin(-m.pi/2),0*sy.cos(theta1)],[sy.sin(theta1),sy.cos(theta1)*sy.cos(-m.pi/2),-sy.cos(theta1)*sy.sin(-m.pi/2),0*sy.sin(theta1)],[0,sy.sin(-m.pi/2),sy.cos(-m.pi/2),114.3],[0,0,0,1]])

T2 = sy.Matrix([[sy.cos(theta2),-sy.sin(theta2)*sy.cos(m.pi/2),sy.sin(theta2)*sy.sin(m.pi/2),0*sy.cos(theta2)],[sy.sin(theta2),sy.cos(theta2)*sy.cos(m.pi/2),-sy.cos(theta2)*sy.sin(m.pi/2),0*sy.sin(theta2)],[0,sy.sin(m.pi/2),sy.cos(m.pi/2),102.616],[0,0,0,1]])

T3 = sy.Matrix([[sy.cos(0),-sy.sin(0)*sy.cos(0),sy.sin(0)*sy.sin(0),0*sy.cos(0)],[sy.sin(0),sy.cos(0)*sy.cos(0),-sy.cos(0)*sy.sin(0),0*sy.sin(0)],[0,sy.sin(0),sy.cos(0),77.216],[0,0,0,1]])
T4 = sy.Matrix([[sy.cos(theta3+m.pi/2),-sy.sin(theta3+m.pi/2)*sy.cos(0),sy.sin(theta3+m.pi/2)*sy.sin(0),51.8*sy.cos(theta3+m.pi/2)],[sy.sin(theta3+m.pi/2),sy.cos(theta3+m.pi/2)*sy.cos(0),-sy.cos(theta3+m.pi/2)*sy.sin(0),51.8*sy.sin(theta3+m.pi/2)],[0,sy.sin(0),sy.cos(0),0],[0,0,0,1]])

T5 = sy.Matrix([[sy.cos(-m.pi/2),-sy.sin(-m.pi/2)*sy.cos(0),sy.sin(-m.pi/2)*sy.sin(0),0*sy.cos(-m.pi/2)],[sy.sin(-m.pi/2),sy.cos(-m.pi/2)*sy.cos(0),-sy.cos(-m.pi/2)*sy.sin(0),0*sy.sin(-m.pi/2)],[0,sy.sin(0),sy.cos(0),127],[0,0,0,1]])
T6 = sy.Matrix([[sy.cos(0),-sy.sin(0)*sy.cos(-m.pi/2),sy.sin(0)*sy.sin(-m.pi/2),101.6*sy.cos(0)],[sy.sin(0),sy.cos(0)*sy.cos(-m.pi/2),-sy.cos(0)*sy.sin(-m.pi/2),101.6*sy.sin(0)],[0,sy.sin(-m.pi/2),sy.cos(-m.pi/2),0],[0,0,0,1]])
T7 = sy.Matrix([[sy.cos(theta4),-sy.sin(theta4)*sy.cos(-m.pi/2),sy.sin(theta4)*sy.sin(-m.pi/2),0*sy.cos(theta4)],[sy.sin(theta4),sy.cos(theta4)*sy.cos(-m.pi/2),-sy.cos(theta4)*sy.sin(-m.pi/2),0*sy.sin(theta4)],[0,sy.sin(-m.pi/2),sy.cos(-m.pi/2),50.8],[0,0,0,1]])

T8 = sy.Matrix([[sy.cos(0),-sy.sin(0)*sy.cos(0),sy.sin(0)*sy.sin(0),-101.6*sy.cos(0)],[sy.sin(0),sy.cos(0)*sy.cos(0),-sy.cos(0)*sy.sin(0),-101.6*sy.sin(0)],[0,sy.sin(0),sy.cos(0),0],[0,0,0,1]])
T9 = sy.Matrix([[sy.cos(0),-sy.sin(0)*sy.cos(0),sy.sin(0)*sy.sin(0),0*sy.cos(0)],[sy.sin(0),sy.cos(0)*sy.cos(0),-sy.cos(0)*sy.sin(0),0*sy.sin(0)],[0,sy.sin(0),sy.cos(0),-128],[0,0,0,1]])
T10 = sy.Matrix([[sy.cos(theta5),-sy.sin(theta5)*sy.cos(-m.pi/2),sy.sin(theta5)*sy.sin(-m.pi/2),0*sy.cos(theta5)],[sy.sin(theta5),sy.cos(theta5)*sy.cos(-m.pi/2),-sy.cos(theta5)*sy.sin(-m.pi/2),0*sy.sin(theta5)],[0,sy.sin(-m.pi/2),sy.cos(-m.pi/2),-76.2],[0,0,0,1]])
T11 = sy.Matrix([[sy.cos(0),-sy.sin(0)*sy.cos(0),sy.sin(0)*sy.sin(0),0*sy.cos(0)],[sy.sin(0),sy.cos(0)*sy.cos(0),-sy.cos(0)*sy.sin(0),0*sy.sin(0)],[0,sy.sin(0),sy.cos(0),-51.8],[0,0,0,1]])
T12 = sy.Matrix([[sy.cos(theta6),-sy.sin(theta6)*sy.cos(m.pi/2),sy.sin(theta6)*sy.sin(m.pi/2),0*sy.cos(theta6)],[sy.sin(theta6),sy.cos(theta6)*sy.cos(m.pi/2),-sy.cos(theta6)*sy.sin(m.pi/2),0*sy.sin(theta6)],[0,sy.sin(m.pi/2),sy.cos(m.pi/2),-153.42],[0,0,0,1]])
T13 = sy.Matrix([[sy.cos(0),-sy.sin(0)*sy.cos(m.pi),sy.sin(0)*sy.sin(m.pi),102.55*sy.cos(0)],[sy.sin(0),sy.cos(0)*sy.cos(m.pi),-sy.cos(0)*sy.sin(m.pi),102.55*sy.sin(0)],[0,sy.sin(m.pi),sy.cos(m.pi),77.19],[0,0,0,1]])
T14 = sy.Matrix([[sy.cos(theta7),-sy.sin(theta7)*sy.cos(0),sy.sin(theta7)*sy.sin(0),0*sy.cos(theta7)],[sy.sin(theta7),sy.cos(theta7)*sy.cos(0),-sy.cos(theta7)*sy.sin(0),0*sy.sin(theta7)],[0,sy.sin(0),sy.cos(0),-133.5],[0,0,0,1]])
T15 = sy.Matrix([[sy.cos(m.pi/2),-sy.sin(m.pi/2)*sy.cos(m.pi),sy.sin(m.pi/2)*sy.sin(m.pi),66.3*sy.cos(m.pi/2)],[sy.sin(m.pi/2),sy.cos(m.pi/2)*sy.cos(m.pi),-sy.cos(m.pi/2)*sy.sin(m.pi),66.3*sy.sin(m.pi/2)],[0,sy.sin(m.pi),sy.cos(m.pi),0],[0,0,0,1]])



T17=T1*T2*T3*T4*T5*T6*T7*T8*T9*T10*T11*T12*T13*T14*T15

# sy.pprint(T17)

# %%
M01 = T1
M02 = T1*T2
M03 = M02*T3*T4
M04 = M03*T5*T6*T7
M05 = M04*T8*T9*T10
M06 = M05*T11*T12
M07 = M06*T13*T14*T15

# %%
sy.pprint(M01)
# Out:
# ⎡cos(θ₁)  -6.12323399573677e-17⋅sin(θ₁)      -1.0⋅sin(θ₁)        0  ⎤
# ⎢                                                                   ⎥
# ⎢sin(θ₁)  6.12323399573677e-17⋅cos(θ₁)       1.0⋅cos(θ₁)         0  ⎥
# ⎢                                                                   ⎥
# ⎢   0                 -1.0               6.12323399573677e-17  114.3⎥
# ⎢                                                                   ⎥
# ⎣   0                   0                         0              1  ⎦

# %%
sy.pprint(M02)
# Out:
# ⎡-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂)    -3.74939945665464e
# ⎢
# ⎢sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁)   -6.12323399573677e-1
# ⎢
# ⎢                     -1.0⋅sin(θ₂)                                           6
# ⎢
# ⎣                           0
#
# -33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁)    6.1232
#
# 7⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁)  1.0⋅si
#
# .12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂)
#
#                         0
#
# 3399573677e-17⋅sin(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅sin(θ₁) + 1.0⋅sin(θ₂)⋅co
#
# n(θ₁)⋅sin(θ₂) - 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅co
#
#                      1.0⋅cos(θ₂) + 3.74939945665464e-33
#
#                                       0
#
# s(θ₁)  -102.616⋅sin(θ₁)⎤
#                        ⎥
# s(θ₁)  102.616⋅cos(θ₁) ⎥
#                        ⎥
#             114.3      ⎥
#                        ⎥
#               1        ⎦

# %%
sy.pprint(M03)
# Out:
# ⎡ (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963
# ⎢
# ⎢(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.570796326
# ⎢
# ⎢                                            (6.12323399573677e-17 - 6.1232339
# ⎢
# ⎣
#
# 267949) + (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e
#
# 7949) + (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅
#
# 9573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - sin(θ₂)⋅cos(θ₃ + 1.5707963267
#
#                         0
#
# -17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949)     -(-6.12323399573677e-17⋅sin
#
# cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949)  -(sin(θ₁)⋅cos(θ₂) + 6.123233
#
# 949)
#
#
#
# (θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + (-3.74939945665464
#
# 99573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + (-6.12323399573677e-
#
#               (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1
#
#                                                                          0
#
# e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃
#
# 17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ
#
# .5707963267949) + 1.0⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949)
#
#
#
# + 1.5707963267949)    6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) - 6.12323399573677e
#
# ₃ + 1.5707963267949)  1.0⋅sin(θ₁)⋅sin(θ₂) - 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ
#
#                                                  1.0⋅cos(θ₂) + 3.7493994566546
#
#                                                                   0
#
# -17⋅sin(θ₁) + 1.0⋅sin(θ₂)⋅cos(θ₁)   51.8⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂
#
# ₂) + 6.12323399573677e-17⋅cos(θ₁)  51.8⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-1
#
# 4e-33
#
#
#
# ) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 51.8⋅(-3.74939945665464e-33⋅s
#
# 7⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 51.8⋅(-6.12323399573677e-17⋅sin
#
#                              51.8⋅(6.12323399573677e-17 - 6.12323399573677e-17
#
#
#
# in(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.57
#
# (θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.
#
# ⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - 51.8⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) +
#
#                          1
#
# 07963267949) + 4.7281163621481e-15⋅sin(θ₁)⋅cos(θ₂) - 102.616⋅sin(θ₁) + 77.216⋅
#
# 5707963267949) + 77.216⋅sin(θ₁)⋅sin(θ₂) - 4.7281163621481e-15⋅cos(θ₁)⋅cos(θ₂)
#
#  77.216⋅cos(θ₂) + 114.3
#
#
#
# sin(θ₂)⋅cos(θ₁)  ⎤
#                  ⎥
# + 102.616⋅cos(θ₁)⎥
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎦

# %%
sy.pprint(M04)
# Out:
# ⎡      (1.0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ +
# ⎢
# ⎢(1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707
# ⎢
# ⎢
# ⎢
# ⎣
#
#  1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂
#
# 963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(
#
#
#
#
#
# ) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.7493
#
# θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.123233995736
#
#                                                    (6.12323399573677e-17⋅(6.12
#
#
#
# 9945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁
#
# 77e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅s
#
# 323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (
#
#
#
# ))⋅sin(θ₃ + 1.5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁
#
# in(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945
#
# 6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949)
#
#
#
# ) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) +
#
# 665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) +
#
#  - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1
#
#
#
#  (-3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ
#
#  (-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁
#
# .5707963267949))⋅cos(θ₄) + (6.12323399573677e-17⋅(6.12323399573677e-17 - 6.123
#
#                                                               0
#
# ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅si
#
# ))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323
#
# 23399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(6.1
#
#
#
# n(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e
#
# 399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-1
#
# 2323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) +
#
#
#
# -17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅si
#
# 7⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂
#
# 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅
#
#
#
# n(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.7493994566
#
# ) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.12323399
#
# sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅sin(θ₄)
#
#
#
# 5464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos
#
# 573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁
#
#
#
#
#
# (θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.123233995736
#
# ))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅
#
#
#
#
#
# 77e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅sin(θ₄)                 6.12323399573677e-17
#
# cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅sin(θ₄)  6.12323399573677e-17⋅(sin(θ₁)
#
#
#
#
#
# ⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.57079632
#
# ⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (
#
#
#
#
#
# 67949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.
#
# sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.57079632679
#
#
#
#
#
# 5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399
#
# 49) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅co
#
#
#
#
#
# 573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(
#
# s(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(-6.1232
#
#                                                         -(6.12323399573677e-17
#
#
#
# -3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)
#
# 3399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅co
#
#  - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e
#
#
#
# ⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(-6.1232339957
#
# s(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(sin(θ₁)⋅cos(θ₂)
#
# -17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.570796326
#
#
#
# 3677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.1232
#
# + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399
#
# 7949) - 6.12323399573677e-17⋅(6.12323399573677e-17⋅(6.12323399573677e-17 - 6.1
#
#
#
# 3399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ
#
# 573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1
#
# 2323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (6.12323399573677e-17 -
#
#
#
# ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos
#
# .5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂)
#
#  6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - sin(θ₂)⋅sin(θ₃ + 1.
#
#
#
# (θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796326794
#
# + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949
#
# 5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949))⋅sin(θ
#
#
#
# 9) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅s
#
# ) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(
#
# ₄) + 6.12323399573677e-17⋅(6.12323399573677e-17⋅(6.12323399573677e-17 - 6.1232
#
#                        0
#
# in(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(-3.
#
# θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(
#
# 3399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(6.12
#
#
#
# 74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅s
#
# -3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))
#
# 323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3
#
#
#
# in(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)
#
# ⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.1232339
#
# .74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅s
#
#
#
# ⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(
#
# 9573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅
#
# in(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅cos(θ₄) - 6
#
#
#
# -3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)
#
# (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂)
#
# .12323399573677e-17⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) + 1.0⋅sin(θ₂)⋅cos(θ₃ + 1
#
#
#
# ⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e
#
# + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.1232339957
#
# .5707963267949) - 6.12323399573677e-17⋅cos(θ₂) - 2.29584502165847e-49
#
#
#
# -33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ +
#
# 3677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))
#
#
#
#
#
#  1.5707963267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-1
#
# ⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅co
#
#
#
#
#
# 7⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) - 3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) +
#
# s(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) - 6.12323399573677e-17⋅sin(θ₁)⋅s
#
#
#
#
#
# 3.74939945665464e-33⋅sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁)
#
# in(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) - 3.74939945665464e-33⋅cos(θ₁)
#
#
#
#
#
#          -3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁
#
# -3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))
#
#
#
#
#
# )⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677
#
# ⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.1232339
#
#
#
#
#
# e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399
#
# 9573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅
#
#
#
#
#
# 573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677
#
# (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂)
#
#
#
#
#
# e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.749
#
# + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.1232339957
#
#           6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅co
#
#
#
# 39945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ
#
# 3677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))
#
# s(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(6.12323399573677e-17
#
#
#
# ₁))⋅cos(θ₃ + 1.5707963267949) - (1.0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) +
#
# ⋅cos(θ₃ + 1.5707963267949) - (1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(
#
# - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - (6.12323399573677e
#
#
#
# cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399
#
# θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂)
#
# -17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.570796326
#
#
#
# 573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12
#
#  + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.1232339
#
# 7949) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.57079
#
#
#
# 323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399
#
# 9573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(
#
# 63267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅c
#
#
#
# 573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.74939945665464e-33
#
# θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅
#
# os(θ₃ + 1.5707963267949))⋅sin(θ₄) + 1.0⋅(6.12323399573677e-17⋅(6.1232339957367
#
#                                                       0
#
# ⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.
#
# sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ +
#
# 7e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.7493994566
#
#
#
# 5707963267949))⋅sin(θ₄) + 1.0⋅(-3.74939945665464e-33⋅(-6.12323399573677e-17⋅si
#
#  1.5707963267949))⋅sin(θ₄) + 1.0⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.1
#
# 5464e-33⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707
#
#
#
# n(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e
#
# 2323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.1232339957367
#
# 963267949) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.123233
#
#
#
# -17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.57079
#
# 7e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707
#
# 99573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-3
#
#
#
# 63267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(
#
# 963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.7
#
# 3)⋅cos(θ₄) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.123233
#
#
#
# θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.7493
#
# 4939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3
#
# 99573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅cos(θ₂)
#
#
#
# 9945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.1232339957
#
# .74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e
#
# + 1.40579962855621e-65
#
#
#
# 3677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin
#
# -33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂)
#
#
#
#
#
# (θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) + 2.295
#
#  + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄
#
#
#
#
#
# 84502165847e-49⋅sin(θ₁)⋅cos(θ₂) - 2.29584502165847e-49⋅sin(θ₁) + 3.74939945665
#
# ) + 3.74939945665464e-33⋅sin(θ₁)⋅sin(θ₂) - 2.29584502165847e-49⋅cos(θ₁)⋅cos(θ₂
#
#
#
#
#
# 464e-33⋅sin(θ₂)⋅cos(θ₁)              101.6⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(
#
# ) + 2.29584502165847e-49⋅cos(θ₁)  101.6⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-1
#
#
#
#
#
# θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 102.6⋅(-6.12323399573677e-1
#
# 7⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 102.6⋅(sin(θ₁)⋅cos(θ₂) + 6.1232
#
#                                                                         102.6⋅
#
#
#
# 7⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 102.6⋅(-3.749
#
# 3399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 102.6⋅(-6.12323399
#
# (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949
#
#
#
# 39945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ
#
# 573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁
#
# ) - 101.6⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.570
#
#                                                          1
#
# ₁))⋅sin(θ₃ + 1.5707963267949) - 101.6⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) -
#
# ))⋅sin(θ₃ + 1.5707963267949) - 101.6⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) +
#
# 7963267949) - 101.6⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 102.6⋅sin(θ₂)⋅cos(θ₃ +
#
#
#
#  sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 1
#
# 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949)
#
#  1.5707963267949) + 204.216⋅cos(θ₂) + 114.3
#
#
#
# .25046235367338e-14⋅sin(θ₁)⋅cos(θ₂) - 102.616⋅sin(θ₁) + 204.216⋅sin(θ₂)⋅cos(θ₁
#
# + 204.216⋅sin(θ₁)⋅sin(θ₂) - 1.25046235367338e-14⋅cos(θ₁)⋅cos(θ₂) + 102.616⋅cos
#
#
#
#
#
# )   ⎤
#     ⎥
# (θ₁)⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎦

# %%
sy.pprint(M05)
# Out:
# ⎡               ((1.0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂)
# ⎢
# ⎢((1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570
# ⎢
# ⎢
# ⎢
# ⎣
#
# )⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(
#
# 7963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin
#
#
#
#
#
# θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-1
#
# (θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573
#
#
#
#
#
# 7⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(
#
# 677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅
#
#
#
#
#
# θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂
#
# sin(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.7493994
#
#
#
#
#
# ) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))
#
# 5665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄)
#
#
#
#
#
# ⋅cos(θ₄) + (-3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos
#
# + (-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ
#
#                                                           ((6.12323399573677e-
#
#
#
# (θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573
#
# ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.1232
#
# 17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267
#
#
#
# 677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323
#
# 3399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-
#
# 949) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.570796
#
#
#
# 399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573
#
# 17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ
#
# 3267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅co
#
#
#
# 677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.
#
# ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.1232339
#
# s(θ₃ + 1.5707963267949))⋅cos(θ₄) + (6.12323399573677e-17⋅(6.12323399573677e-17
#
#
#
# 74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅co
#
# 9573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ
#
#  - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e
#
#
#
# s(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12
#
# ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)
#
# -33⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.570796326
#
#
#
# 323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅sin(θ₄))⋅cos(θ₅) + (6.123233995736
#
# ⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅sin(θ₄))⋅cos(θ₅) + (6.12323399573677e
#
# 7949) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573
#
#
#
# 77e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.57
#
# -17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796
#
# 677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅si
#
#
#
# 07963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ
#
# 3267949) - (sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1
#
# n(θ₄))⋅cos(θ₅) + (-(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ
#
#
#
# ₃ + 1.5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12
#
# .5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-3
#
# ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399
#
#
#
# 323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677
#
# 3⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e
#
# 573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(6.123233
#
#                                                 0
#
# e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅s
#
# -17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(
#
# 99573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.
#
#
#
# in(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(-6.1232
#
# θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(sin(
#
# 5707963267949) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃
#
#
#
# 3399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) +
#
# θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949)
#
# + 1.5707963267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅
#
#
#
# 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))
#
# + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁)
#
# sin(θ₂)⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(6.123233995
#
#
#
# ⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ
#
# )⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(
#
# 73677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.570
#
#
#
# ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796
#
# θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5
#
# 7963267949) + 3.74939945665464e-33⋅(6.12323399573677e-17 - 6.12323399573677e-1
#
#
#
# 3267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677
#
# 707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅
#
# 7⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1
#
#
#
# e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-1
#
# cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399
#
# .5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos
#
#
#
# 7⋅(-3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(
#
# 573677e-17⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(
#
# (θ₂) - 3.74939945665464e-33)⋅cos(θ₄) - 6.12323399573677e-17⋅sin(θ₂)⋅sin(θ₃ + 1
#
#
#
# θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅s
#
# θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂)
#
# .5707963267949) + 1.0⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17
#
#
#
# in(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677
#
#  + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.1232339
#
# ⋅cos(θ₂) - 2.29584502165847e-49)⋅sin(θ₅)
#
#
#
# e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅s
#
# 9573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(
#
#
#
#
#
# in(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.749399456
#
# θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-
#
#
#
#
#
# 65464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅co
#
# 6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) +
#
#
#
#
#
# s(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573
#
# 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-1
#
#
#
#
#
# 677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) - 3.74939945665464e-33⋅sin(θ₁)⋅cos(
#
# 7⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) - 6.12323399573677e-
#
#
#
#
#
# θ₂) + 3.74939945665464e-33⋅sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin
#
# 17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) - 3.74939945665464e-
#
#
#
#
#
# (θ₅)                                         -6.12323399573677e-17⋅((1.0⋅(-6.1
#
# 33⋅cos(θ₁))⋅sin(θ₅)  -6.12323399573677e-17⋅((1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399
#
#
#
#
#
# 2323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949)
#
# 573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(
#
#
#
#
#
#  + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ
#
# sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.57079632679
#
#
#
#
#
# ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅si
#
# 49) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945
#
#
#
#
#
# n(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570
#
# 665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-6.1232
#
#
#
#
#
# 7963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573
#
# 3399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅co
#
#
#
#
#
# 677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) + (-3.749399456654
#
# s(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) + (-3.74939945665464e-33⋅(sin(θ₁)⋅co
#
#
#
#
#
# 64e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.57
#
# s(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12
#
#
#
#
#
# 07963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + c
#
# 323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(
#
#
#
#
#
# os(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.749399456
#
# θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅si
#
#
#
#
#
# 65464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅si
#
# n(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963
#
#
#
#
#
# n(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅
#
# 267949) + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.7493
#
#          -6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅co
#
#
#
# cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.570796326
#
# 9945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(
#
# s(θ₂))⋅sin(θ₃ + 1.5707963267949) - 3.74939945665464e-33⋅(6.12323399573677e-17
#
#
#
# 7949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) -
#
# θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(
#
# - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-
#
#
#
# sin(θ₂)⋅cos(θ₁))⋅sin(θ₄))⋅sin(θ₅) + 3.74939945665464e-33⋅(-6.12323399573677e-1
#
# θ₁))⋅sin(θ₄))⋅sin(θ₅) + 3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.123233995736
#
# 17⋅((6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂)
#
#
#
# 7⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573
#
# 77e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(sin(
#
# )⋅sin(θ₃ + 1.5707963267949) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos
#
#
#
# 677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5
#
# θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949)
#
# (θ₂))⋅cos(θ₃ + 1.5707963267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.123233
#
#
#
# 707963267949) - 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) -
#
# - 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.749399456654
#
# 99573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) + (6.12323399573677e-1
#
#
#
# sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 3.
#
# 64e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 3.7493994566
#
# 7⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.57079632679
#
#
#
# 74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.123233
#
# 5464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)
#
# 49) + 3.74939945665464e-33⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂
#
#
#
# 99573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 1.0⋅(1.0⋅(-6.1232339
#
# ⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 1.0⋅(1.0⋅(sin(θ₁)⋅cos(θ₂)
#
# ))⋅cos(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963
#
#
#
# 9573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.1
#
# + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399
#
# 267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3
#
#
#
# 2323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅co
#
# 573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1
#
# .74939945665464e-33)⋅sin(θ₄))⋅sin(θ₅) + 1.0⋅(6.12323399573677e-17⋅(6.123233995
#
#
#
# s(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅
#
# .5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂)
#
# 73677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (6.12323
#
#
#
# cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796326
#
# + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949
#
# 399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - sin(
#
#
#
# 7949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-1
#
# ) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(
#
# θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.570796
#
#
#
# 7⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) - (-3.74939945665464e-33
#
# θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) - (-3.74939945665464e-33
#
# 3267949))⋅sin(θ₄) - (6.12323399573677e-17⋅(6.12323399573677e-17 - 6.1232339957
#
#
#
# ⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.57079632
#
# ⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796326
#
# 3677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(6.12323399
#
#
#
# 67949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)
#
# 7949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅c
#
# 573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3.74939
#
#                                                                     0
#
# ⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e
#
# os(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-1
#
# 945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)
#
#
#
# -33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ +
#
# 7⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃
#
# ⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅cos(θ₄) + 6.12323
#
#
#
#  1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂
#
#  + 1.5707963267949) + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(
#
# 399573677e-17⋅(-(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ +
#
#
#
# ) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949)
#
# θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.570796326
#
#  1.5707963267949) - 6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573
#
#
#
# - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂
#
# 7949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573
#
# 677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(6.123233995
#
#
#
# )⋅cos(θ₁))⋅cos(θ₄) + 6.12323399573677e-17⋅(6.12323399573677e-17⋅(-6.1232339957
#
# 677e-17⋅cos(θ₁))⋅cos(θ₄) + 6.12323399573677e-17⋅(6.12323399573677e-17⋅(sin(θ₁)
#
# 73677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.570
#
#
#
# 3677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (-6.12
#
# ⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (
#
# 7963267949) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1
#
#
#
# 323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949)
#
# sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.57079632679
#
# .5707963267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin
#
#
#
# - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(
#
# 49) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅co
#
# (θ₂)⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(6.123233995736
#
#
#
# θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(-3.749399456654
#
# s(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(-6.1232
#
# 77e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.570796
#
#
#
# 64e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ
#
# 3399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅co
#
# 3267949) + 3.74939945665464e-33⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅c
#
#
#
# ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(-6.12323399573677e-17⋅sin(θ₁
#
# s(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(sin(θ₁)⋅cos(θ₂)
#
# os(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.57
#
#
#
# )⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅
#
# + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399
#
# 07963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂
#
#
#
# (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.570796326
#
# 573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1
#
# ) - 3.74939945665464e-33)⋅cos(θ₄) - 6.12323399573677e-17⋅sin(θ₂)⋅sin(θ₃ + 1.57
#
#
#
# 7949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁)
#
# .5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂)
#
# 07963267949) + 1.0⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅co
#
#
#
# - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.749399
#
# + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949
#
# s(θ₂) - 2.29584502165847e-49)⋅cos(θ₅) - 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ +
#
#
#
# 45665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))
#
# ) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(
#
# 1.5707963267949) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - 3.
#
#
#
# ⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(-3.74939945665464e
#
# θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(
#
# 74939945665464e-33⋅cos(θ₂) - 1.40579962855621e-65
#
#
#
# -33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.57079
#
# -3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))
#
#
#
#
#
# 63267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(
#
# ⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.1232339
#
#
#
#
#
# θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.749399456654
#
# 9573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅
#
#
#
#
#
# 64e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ
#
# (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂)
#
#
#
#
#
# ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos
#
# + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.1232339957
#
# ...
#
# os(θ₃ + 1.5707963267949) + 204.2⋅(1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅
#
#
#
#
#
# sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-
#
# sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos
#
#                                          102.6⋅(6.12323399573677e-17 - 6.12323
#
#
#
# 6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.57079632679
#
# (θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.123
#
# 399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - 101.6⋅(6.12323399573677e-17
#
#
#
# 49) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) -
#
# 23399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅
#
#  - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 204.2⋅(6.12323399
#
#
#
# 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.74939945
#
# cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-6.12323399573677e
#
# 573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.57
#
#
#
# 665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅c
#
# -17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(
#
# 07963267949) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ +
#
#
#
# os(θ₃ + 1.5707963267949))⋅sin(θ₄) - 101.6⋅(1.0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅
#
# θ₃ + 1.5707963267949))⋅sin(θ₄) - 101.6⋅(1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.1232339957367
#
# 1.5707963267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅si
#
#
#
# sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-
#
# 7e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ
#
# n(θ₂)⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) - 101.6⋅(6.12323399573677e-17⋅(6.1232
#
#
#
# 6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.57079632679
#
# ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) +
#
# 3399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (6.
#
#
#
# 49) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) -
#
#  6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.7493994566546
#
# 12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) -
#
#
#
# 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.74939945
#
# 4e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-6.123233995
#
#  sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5
#
#
#
# 665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅c
#
# 73677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁)
#
# 707963267949))⋅cos(θ₄) - 101.6⋅(6.12323399573677e-17⋅(6.12323399573677e-17 - 6
#
#                                                                  1
#
# os(θ₃ + 1.5707963267949))⋅cos(θ₄) - 101.6⋅(-3.74939945665464e-33⋅(-6.123233995
#
# )⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) - 101.6⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅c
#
# .12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅
#
#
#
# 73677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.123
#
# os(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.1
#
# (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949
#
#
#
# 23399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(
#
# 2323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos
#
# ) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e
#
#
#
# θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅co
#
# (θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅s
#
# -17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅sin(θ₄
#
#
#
# s(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.57079632679
#
# in(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.570796
#
# ) - 204.2⋅(6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅c
#
#
#
# 49) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) -
#
# 3267949) + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.749
#
# os(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(6.12323399573677e-17
#
#
#
# 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.1232339957
#
# 39945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin
#
#  - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3.74939945665464e
#
#
#
# 3677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅sin
#
# (θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos
#
# -33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ +
#
#
#
# (θ₄) - 204.2⋅(-3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + c
#
# (θ₁))⋅sin(θ₄) - 204.2⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.123233995736
#
# 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅cos(θ₄) - 101.6⋅sin(θ₂)⋅sin
#
#
#
# os(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.123233995
#
# 77e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(
#
# (θ₃ + 1.5707963267949) - 102.6⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) + 204.216⋅cos
#
#
#
# 73677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.123
#
# θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949)
#
# (θ₂) + 114.3
#
#
#
# 23399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.123233995
#
# + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.749399456654
#
#
#
#
#
# 73677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-
#
# 64e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.7493994566
#
#
#
#
#
# 3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅
#
# 5464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)
#
#
#
#
#
# cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.
#
# ⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.123233
#
#
#
#
#
# 12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) + 1.25046235367338e-14⋅s
#
# 99573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) + 204.216
#
#
#
#
#
# in(θ₁)⋅cos(θ₂) - 102.616⋅sin(θ₁) + 204.216⋅sin(θ₂)⋅cos(θ₁)               ⎤
#                                                                          ⎥
# ⋅sin(θ₁)⋅sin(θ₂) - 1.25046235367338e-14⋅cos(θ₁)⋅cos(θ₂) + 102.616⋅cos(θ₁)⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎦

# %%
sy.pprint(M06)
# Out:
# ⎡                                       (((1.0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅
# ⎢
# ⎢(((1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.57
# ⎢
# ⎢
# ⎢
# ⎣
#
# sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-
#
# 07963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅si
#
#
#
#
#
# 6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.57079632679
#
# n(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.1232339957
#
#
#
#
#
# 49) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) -
#
# 3677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))
#
#
#
#
#
# 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.74939945
#
# ⋅sin(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.749399
#
#
#
#
#
# 665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅c
#
# 45665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄)
#
#
#
#
#
# os(θ₃ + 1.5707963267949))⋅cos(θ₄) + (-3.74939945665464e-33⋅(-6.12323399573677e
#
#  + (-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(
#
#
#
#
#
# -17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.123233995
#
# θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.123
#
#
#
#
#
# 73677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1
#
# 23399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e
#
#
#
#
#
# .5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂)
#
# -17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(
#
#
#
#
#
# - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) +
#
# θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.123233
#
#
#
#
#
# 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.1232
#
# 99573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(
#
#
#
#
#
# 3399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-
#
# θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁
#
#
#
#
#
# 17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅sin(θ₄))⋅
#
# )⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅sin(θ₄))⋅cos(θ₅) + (6.12323399573677
#
#
#
#
#
# cos(θ₅) + (6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ
#
# e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.57079
#
#
#
#
#
# ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂)
#
# 63267949) - (sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ +
#
#
#
#
#
#  + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)
#
# 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-
#
#
#
#
#
# ⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.57079632
#
# 33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677
#
#                                               (((6.12323399573677e-17⋅(6.12323
#
#
#
# 67949) - 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁)
#
# e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos
#
# 399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (6.1
#
#
#
#  - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.1232339
#
# (θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(sin
#
# 2323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) -
#
#
#
# 9573677e-17⋅(1.0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin
#
# (θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949)
#
# sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.57
#
#
#
# (θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅s
#
#  + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁
#
# 07963267949))⋅cos(θ₄) + (6.12323399573677e-17⋅(6.12323399573677e-17 - 6.123233
#
#
#
# in(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3
#
# ))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin
#
# 99573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(6.1232
#
#
#
# .74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅c
#
# (θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.
#
# 3399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3.7
#
#
#
# os(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - s
#
# 5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33
#
# 4939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin
#
#
#
# in(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(
#
# ⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.1232339
#
# (θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅sin(θ₄))⋅cos(
#
#
#
# θ₄) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ
#
# 9573677e-17⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin
#
# θ₅) + (-(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.57079
#
#
#
# ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17
#
# (θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂
#
# 63267949) - 6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅
#
#
#
# ⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.57079632
#
# ) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.123233
#
# cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(6.12323399573677e-1
#
#
#
# 67949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁)
#
# 99573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos
#
# 7⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.57079632679
#
#
#
#  - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.7493994
#
# (θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(
#
# 49) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963
#
#
#
# 5665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.1232339957367
#
# -6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) +
#
# 267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos
#
#
#
# 7e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₁
#
#  1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-
#
# (θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(6.12323399573677e-17⋅(
#
#
#
# )⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) - 3.749399
#
# 17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) - 6.12323399573677e
#
# 6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949)
#
#
#
# 45665464e-33⋅sin(θ₁)⋅cos(θ₂) + 3.74939945665464e-33⋅sin(θ₁) - 6.12323399573677
#
# -17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) - 3.74939945665464e
#
#  + 3.74939945665464e-33⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅
#
#
#
# e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₅))⋅cos(θ₆) + (-6.12323399573677e-17⋅((1.0⋅(-6.1232
#
# -33⋅cos(θ₁))⋅sin(θ₅))⋅cos(θ₆) + (-6.12323399573677e-17⋅((1.0⋅(sin(θ₁)⋅cos(θ₂)
#
# cos(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267
#
#
#
# 3399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) +
#
# + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399
#
# 949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74
#
#
#
# 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))
#
# 573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1
#
# 939945665464e-33)⋅cos(θ₄) - 6.12323399573677e-17⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267
#
#
#
# ⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ
#
# .5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂)
#
# 949) + 1.0⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅cos(θ₂) -
#
#
#
# ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796
#
# + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949
#
# 2.29584502165847e-49)⋅sin(θ₅))⋅cos(θ₆) + (-6.12323399573677e-17⋅(6.12323399573
#
#
#
# 3267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677
#
# ) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(
#
# 677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - 3.74939945
#
#
#
# e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) + (-3.74939945665464e
#
# θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) + (-3.74939945665464e-33
#
# 665464e-33⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.57
#
#
#
# -33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.57079
#
# ⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796326
#
# 07963267949) - 6.12323399573677e-17⋅((6.12323399573677e-17⋅(6.12323399573677e-
#
#
#
# 63267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(
#
# 7949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅c
#
# 17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (6.123233995736
#
#
#
# θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.749399456654
#
# os(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-1
#
# 77e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - sin(θ₂)⋅sin
#
#
#
# 64e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ
#
# 7⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃
#
# (θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949
#
#
#
# ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos
#
#  + 1.5707963267949) + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(
#
# ))⋅cos(θ₄) + (6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-1
#
#                              0
#
# (θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.570796326794
#
# θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.570796326
#
# 7⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(6.12323399573677e
#
#
#
# 9) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin
#
# 7949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573
#
# -17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3.749399456654
#
#
#
# (θ₂)⋅cos(θ₁))⋅sin(θ₄))⋅sin(θ₅) + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅s
#
# 677e-17⋅cos(θ₁))⋅sin(θ₄))⋅sin(θ₅) + 3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.
#
# 64e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃
#
#
#
# in(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677
#
# 12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.123233995736
#
#  + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅sin(θ₄))⋅sin(θ₅) + 1.0⋅(
#
#
#
# e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707
#
# 77e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.570
#
# 6.12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin
#
#
#
# 963267949) - 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin
#
# 7963267949) - 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.
#
# (θ₃ + 1.5707963267949) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))
#
#
#
# (θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 3.749
#
# 74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) -
#
# ⋅cos(θ₃ + 1.5707963267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573
#
#
#
# 39945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.123233995
#
# 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464
#
# 677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) - (6.12323399573677e-17⋅(6.
#
#
#
# 73677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 1.0⋅(1.0⋅(-6.1232339957
#
# e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 1.0⋅(1.0⋅(sin(
#
# 12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) +
#
#
#
# 3677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.1232
#
# θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949)
#
#  3.74939945665464e-33⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅co
#
#
#
# 3399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ
#
# + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁)
#
# s(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.570796326794
#
#
#
# ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos
#
# )⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(
#
# 9) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - cos(θ₂) - 3.7493
#
#
#
# (θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796326794
#
# θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5
#
# 9945665464e-33)⋅cos(θ₄) + 6.12323399573677e-17⋅(-(6.12323399573677e-17 - 6.123
#
#
#
# 9) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅s
#
# 707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅
#
# 23399573677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(6.1
#
#
#
# in(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) - (-3.74939945665464e-33⋅(-
#
# cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) - (-3.749399
#
# 2323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) -
#
#
#
# 6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.57079632679
#
# 45665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ +
#
# 6.12323399573677e-17⋅(6.12323399573677e-17⋅(6.12323399573677e-17 - 6.123233995
#
#
#
# 49) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅co
#
#  1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-
#
# 73677e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (6.12323399573677e-17 - 6.12323
#
#
#
# s(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33
#
# 17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323
#
# 399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - sin(θ₂)⋅sin(θ₃ + 1.57079632
#
#
#
# ⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.
#
# 399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos
#
# 67949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.1
#
#
#
# 5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) -
#
# (θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅
#
# 2323399573677e-17⋅(6.12323399573677e-17⋅(6.12323399573677e-17 - 6.123233995736
#
#
#
#  sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6
#
# sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ +
#
# 77e-17⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(6.1232339957
#
#
#
# .12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅c
#
#  1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6
#
# 3677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3.7493994
#
#
#
# os(θ₁))⋅cos(θ₄) + 6.12323399573677e-17⋅(6.12323399573677e-17⋅(-6.1232339957367
#
# .12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) + 6.12323399573677e-17⋅(6.12323399573677e
#
# 5665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅c
#
#
#
# 7e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (-6.12323
#
# -17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796
#
# os(θ₃ + 1.5707963267949) - cos(θ₂) - 3.74939945665464e-33)⋅cos(θ₄) - 6.1232339
#
#
#
# 399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - (
#
# 3267949) - (sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1
#
# 9573677e-17⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) + 1.0⋅sin(θ₂)⋅cos(θ₃ + 1.5707963
#
#
#
# -3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)
#
# .5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-3
#
# 267949) - 6.12323399573677e-17⋅cos(θ₂) - 2.29584502165847e-49)⋅cos(θ₅) - 3.749
#
#
#
# ⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(-3.74939945665464e
#
# 3⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e
#
# 39945665464e-33⋅sin(θ₂)⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅sin(θ
#
#
#
# -33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ +
#
# -17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(
#
# ₂)⋅cos(θ₃ + 1.5707963267949) - 3.74939945665464e-33⋅cos(θ₂) - 1.40579962855621
#
#
#
#  1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅s
#
# θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(sin(
#
# e-65)⋅sin(θ₆)
#
#
#
# in(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6
#
# θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949)
#
#
#
#
#
# .12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.570796326794
#
# + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁)
#
#
#
#
#
# 9) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6
#
# )⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(
#
#
#
#
#
# .12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.749399456
#
# θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5
#
#
#
#
#
# 65464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅co
#
# 707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅
#
#
#
#
#
# s(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(-3.74939945665464e-33
#
# cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399
#
#
#
#
#
# ⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.57079632
#
# 573677e-17⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(
#
#
#
#
#
# 67949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)
#
# θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂)
#
#
#
#
#
# ⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e
#
#  + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.1232339
#
#
#
#
#
# -33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ +
#
# 9573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(
#
#
#
#
#
#  1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂
#
# θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-
#
# ...
#
#
#
# 9573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.1
#
# ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) +
#
# 4e-33)⋅cos(θ₄) - 205.22⋅(-(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂)
#
#
#
# 2323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.1232339
#
#  6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.7493994566546
#
# )⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(6.12323399573677e-17 - 6.1
#
#
#
# 9573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅
#
# 4e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665
#
# 2323399573677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(6
#
#
#
# (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂
#
# 464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅
#
# .12323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(
#
#
#
# )⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) +
#
# cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.1232339
#
# θ₃ + 1.5707963267949) - (6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅
#
#
#
# 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) - 205.22⋅(6.1232339957
#
# 9573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) - 205.22⋅(
#
# cos(θ₃ + 1.5707963267949) - sin(θ₂)⋅sin(θ₃ + 1.5707963267949) - 6.123233995736
#
#
#
# 3677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.
#
# 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅
#
# 77e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(6.12
#
#
#
# 5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos
#
# sin(θ₃ + 1.5707963267949) - (sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅co
#
# 323399573677e-17⋅(6.12323399573677e-17 - 6.12323399573677e-17⋅cos(θ₂))⋅sin(θ₃
#
#
#
# (θ₃ + 1.5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.
#
# s(θ₁))⋅cos(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.
#
# + 1.5707963267949) + 3.74939945665464e-33⋅(6.12323399573677e-17 - 6.1232339957
#
#
#
# 12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.123233995736
#
# 74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) -
#
# 3677e-17⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅sin(θ₂)⋅sin
#
#
#
# 77e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17
#
# 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464
#
# (θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949
#
#
#
# ⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(-6.12
#
# e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.123233995736
#
# ) - cos(θ₂) - 3.74939945665464e-33)⋅cos(θ₄) - 6.12323399573677e-17⋅sin(θ₂)⋅sin
#
#
#
# 323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949)
#
# 77e-17⋅(1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ +
#
# (θ₃ + 1.5707963267949) + 1.0⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) - 6.12323399573
#
#
#
# + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂
#
# 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-1
#
# 677e-17⋅cos(θ₂) - 2.29584502165847e-49)⋅cos(θ₅) - 101.6⋅sin(θ₂)⋅sin(θ₃ + 1.570
#
#
#
# ))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin
#
# 7⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.123233
#
# 7963267949) - 102.6⋅sin(θ₂)⋅cos(θ₃ + 1.5707963267949) + 204.216⋅cos(θ₂) + 114.
#
#
#
# (θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707
#
# 99573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(
#
# 3
#
#
#
# 963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.123233995736
#
# θ₁))⋅sin(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74
#
#
#
#
#
# 77e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e
#
# 939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin
#
#
#
#
#
# -17⋅(-3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅co
#
# (θ₄) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.123233
#
#
#
#
#
# s(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17
#
# 99573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17
#
#
#
#
#
# ⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.123233995736
#
# ⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.570796326
#
#
#
#
#
# 77e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17
#
# 7949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.749399
#
#
#
#
#
# ⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.7493994
#
# 45665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.7493
#
#
#
#
#
# 5665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅
#
# 9945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅c
#
#
#
#
#
# cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.123233995
#
# os(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.
#
#
#
#
#
# 73677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) - 3.74939945665464e-33⋅sin(θ₁)⋅co
#
# 12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) - 6
#
#
#
#
#
# s(θ₂) + 3.74939945665464e-33⋅sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅c
#
# .12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) - 3
#
#
#
#
#
# os(θ₅) + 1.25046235367338e-14⋅sin(θ₁)⋅cos(θ₂) - 102.616⋅sin(θ₁) + 204.216⋅sin(
#
# .74939945665464e-33⋅cos(θ₁))⋅cos(θ₅) + 204.216⋅sin(θ₁)⋅sin(θ₂) - 1.25046235367
#
#
#
#
#
# θ₂)⋅cos(θ₁)                              ⎤
#                                          ⎥
# 338e-14⋅cos(θ₁)⋅cos(θ₂) + 102.616⋅cos(θ₁)⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎦

# %%
sy.pprint(M07)
# Out:
# ⎡
# ⎢
# ⎢-((((1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#
# 5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅
#
#
#
#
#
#                                                  -((((1.0⋅(-6.12323399573677e-
#
# sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399
#
#
#
#
#
# 17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.1232339957
#
# 573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁
#
#
#
#
#
# 3677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.
#
# ))⋅sin(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.7493
#
#
#
#
#
# 5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) -
#
# 9945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ
#
#
#
#
#
#  sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (
#
# ₄) + (-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅co
#
#
#
#
#
# -3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)
#
# s(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.1
#
#
#
#
#
# ⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) + (-3.74939945665464e-33⋅(-6.1232
#
# 2323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.1232339957367
#
#
#
#
#
# 3399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) +
#
# 7e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅co
#
#
#
#
#
# 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))
#
# s(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.1232
#
#
#
#
#
# ⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ
#
# 3399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅co
#
#
#
#
#
# ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796
#
# s(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(
#
#
#
#
#
# 3267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ
#
# θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅sin(θ₄))⋅cos(θ₅) + (6.123233995736
#
#
#
#
#
# ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323
#
# 77e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570
#
#
#
#
#
# 399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁)
#
# 7963267949) - (sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃
#
#
#
#
#
# )⋅sin(θ₄))⋅cos(θ₅) + (6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(
#
# + 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464
#
#
#
#
#
# θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - (-6.12323399573677e-17⋅sin(
#
# e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.123233995736
#
#
#
#
#
# θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) - (-3.74939945665464e
#
# 77e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅c
#
#
#
#
#
# -33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ +
#
# os(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(s
#
#
#
#
#
#  1.5707963267949) - 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂
#
# in(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.570796326794
#
#
#
#
#
# ) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949)
#
# 9) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(
#
#
#
#
#
# - 6.12323399573677e-17⋅(1.0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅c
#
# θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅s
#
#
#
#
#
# os(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-1
#
# in(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ +
#
#
#
#
#
# 7⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573
#
# 1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-
#
#
#
#
#
# 677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-1
#
# 33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323
#
#
#
#
#
# 7⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅
#
# 399573677e-17⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅s
#
#
#
#
#
# cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.570796326
#
# in(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(
#
#
#
#
#
# 7949))⋅sin(θ₄) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅(-6.1232339957367
#
# θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.1232
#
#
#
#
#
# 7e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.1232339
#
# 3399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅c
#
#
#
#
#
# 9573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ +
#
# os(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33
#
#
#
#
#
#  1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂
#
# ⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂)
#
#
#
#
#
# ) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949)
#
#  + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677
#
#
#
#
#
# + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12
#
# e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) - 6.1232339957367
#
#
#
#
#
# 323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677
#
# 7e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) - 3.7493994566546
#
#
#
#
#
# e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁) - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄)
#
# 4e-33⋅cos(θ₁))⋅sin(θ₅))⋅cos(θ₆) + (-6.12323399573677e-17⋅((1.0⋅(sin(θ₁)⋅cos(θ₂
#
#
#
#
#
#  - 3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) + 3.74939945665464e-33⋅sin(θ₁) - 6.123
#
# ) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.123233
#
#
#
#
#
# 23399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₅))⋅cos(θ₆) + (-6.12323399573677e-17⋅((1
#
# 99573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ +
#
#
#
#
#
# .0⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.570796
#
#  1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂
#
#
#
#
#
# 3267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ
#
# ) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.57079632679
#
#
#
#
#
# ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.7493994566546
#
# 49) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅co
#
#
#
#
#
# 4e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃
#
# s(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) + (-3.74939945665464e-
#
#
#
#
#
#  + 1.5707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.123
#
# 33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963
#
#
#
#
#
# 23399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅cos(θ₄) + (-3.7493
#
# 267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)
#
#
#
#
#
# 9945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ
#
# ⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e
#
#
#
#
#
# ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin
#
# -17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(
#
#
#
#
#
# (θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.7
#
# θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅si
#
#
#
#
#
# 4939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos
#
# n(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963
#
#
#
#
#
# (θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅
#
# 267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.123233995
#
#
#
#
#
# sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5
#
# 73677e-17⋅cos(θ₁))⋅sin(θ₄))⋅sin(θ₅) + 3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) +
#
#
#
#
#
# 707963267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅si
#
# 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.1232339957
#
#
#
#
#
# n(θ₁) - sin(θ₂)⋅cos(θ₁))⋅sin(θ₄))⋅sin(θ₅) + 3.74939945665464e-33⋅(-6.123233995
#
# 3677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5
#
#
#
#
#
# 73677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) - 6.123
#
# 707963267949) - 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) +
#
#
#
#
#
# 23399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(
#
# 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949)
#
#
#
#
#
# θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅co
#
# - 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.749399456654
#
#
#
#
#
# s(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.57079632679
#
# 64e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 1.0⋅(1.0⋅(si
#
#
#
#
#
# 49) - 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) -
#
# n(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949
#
#
#
#
#
# 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 1.0⋅(1.0⋅(-6
#
# ) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ
#
#
#
#
#
# .12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.570796326794
#
# ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅si
#
#
#
#
#
# 9) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos
#
# n(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1
#
#
#
#
#
# (θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅
#
# .5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-3
#
#
#
#
#
# sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5
#
# 3⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) - (-3.7493
#
#
#
#
#
# 707963267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.123233995
#
# 9945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃
#
#
#
#
#
# 73677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) - (-3.7493994566
#
#  + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677
#
#
#
#
#
# 5464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.
#
# e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.123
#
#
#
#
#
# 5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) +
#
# 23399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅c
#
#
#
#
#
#  cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.7493994
#
# os(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.12323399573677e-1
#
#
#
#
#
# 5665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅
#
# 7⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃
#
#
#
#
#
# sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁
#
#  + 1.5707963267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) -
#
#
#
#
#
# )⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963
#
#  6.12323399573677e-17⋅cos(θ₁))⋅cos(θ₄) + 6.12323399573677e-17⋅(6.1232339957367
#
#
#
#
#
# 267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁)
#
# 7e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707
#
#
#
#
#
# - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) + 6.12323399573677e-17⋅(6.12323399573677e-17⋅(-6.12
#
# 963267949) - (sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ +
#
#
#
#
#
# 323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949)
#
#  1.5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e
#
#
#
#
#
# - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963
#
# -33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.1232339957367
#
#
#
#
#
# 267949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e
#
# 7e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅co
#
#
#
#
#
# -17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(-3.7493
#
# s(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(si
#
#
#
#
#
# 9945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁
#
# n(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949
#
#
#
#
#
# ))⋅cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(-6.12323399573677e-1
#
# ) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ
#
#
#
#
#
# 7⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573
#
# ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅si
#
#
#
#
#
# 677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5
#
# n(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1
#
#
#
#
#
# 707963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) -
#
# .5707963267949) - (-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-3
#
#
#
#
#
# sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-
#
# 3⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.123233
#
#
#
#
#
# 3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅
#
# 99573677e-17⋅(-3.74939945665464e-33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅si
#
#
#
#
#
# cos(θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(-3.7493994
#
# n(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ
#
#
#
#
#
# 5665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ +
#
# ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323
#
#
#
#
#
#  1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂
#
# 399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅co
#
#
#
#
#
# ) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.7493
#
# s(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅
#
# ...
#
#  + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665
#
#
#
#
#
# -6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267
#
# 464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - sin(θ₁)⋅sin
#
#
#
#
#
# 949) - (-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17
#
# (θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.12323399573677e-17⋅cos(θ₁))⋅co
#
#
#
#
#
# ⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(-3.7493994
#
# s(θ₄) + 6.12323399573677e-17⋅(6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.123233
#
#
#
#
#
# 5665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅
#
# 99573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (sin(θ₁)⋅cos(θ₂) + 6
#
#
#
#
#
# cos(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(1.0⋅(-6.12323399573677e-17⋅s
#
# .12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) - (-6.123233995
#
#
#
#
#
# in(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677
#
# 73677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁)
#
#
#
#
#
# e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707
#
# )⋅sin(θ₃ + 1.5707963267949) - 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(
#
#
#
#
#
# 963267949) + 6.12323399573677e-17⋅(-3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin
#
# θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5
#
#
#
#
#
# (θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-3.7
#
# 707963267949) - 6.12323399573677e-17⋅(1.0⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e
#
#
#
#
#
# 4939945665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos
#
# -17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(sin(θ₁)
#
#
#
#
#
# (θ₁))⋅cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(-3.7493994566
#
# ⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6
#
#
#
#
#
# 5464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + cos(θ₁)⋅cos(θ₂))⋅sin(θ₃ + 1.
#
# .12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e
#
#
#
#
#
# 5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) +
#
# -33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(θ₃ + 1.5707963267949) - (-6.12323399573
#
#
#
#
#
#  cos(θ₁)⋅cos(θ₂))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-3.7493994
#
# 677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅
#
#
#
#
#
# 5665464e-33⋅sin(θ₁)⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅
#
# cos(θ₃ + 1.5707963267949))⋅sin(θ₄) + 6.12323399573677e-17⋅(-3.74939945665464e-
#
#
#
#
#
# sin(θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-3.74939945665464e-33⋅sin(θ₁
#
# 33⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅sin(θ₃ + 1.5707963
#
#
#
#
#
# )⋅cos(θ₂) - sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₃ + 1.5707963
#
# 267949) + 6.12323399573677e-17⋅(sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₂)
#
#
#
#
#
# 267949) - 6.12323399573677e-17⋅sin(θ₁)⋅cos(θ₂) + 6.12323399573677e-17⋅sin(θ₁)
#
# ⋅cos(θ₁))⋅cos(θ₃ + 1.5707963267949) + 6.12323399573677e-17⋅(-6.12323399573677e
#
#
#
#
#
# - sin(θ₂)⋅cos(θ₁))⋅cos(θ₄) - 3.74939945665464e-33⋅sin(θ₁)⋅cos(θ₂) + 3.74939945
#
# -17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅sin(
#
#
#
#
#
# 665464e-33⋅sin(θ₁) - 6.12323399573677e-17⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₅) - 2.2958450
#
# θ₃ + 1.5707963267949) + 3.74939945665464e-33⋅(-6.12323399573677e-17⋅sin(θ₁)⋅si
#
#
#
#
#
# 2165847e-49⋅sin(θ₁)⋅cos(θ₂) + 2.29584502165847e-49⋅sin(θ₁) - 3.74939945665464e
#
# n(θ₂) + 3.74939945665464e-33⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁))⋅cos(θ₃ + 1.5707963
#
#
#
#
#
# -33⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₆) - 1.40579962855621e-65⋅sin(θ₁)⋅cos(θ₂) + 1.405799
#
# 267949) - sin(θ₁)⋅sin(θ₂) + 6.12323399573677e-17⋅cos(θ₁)⋅cos(θ₂) - 6.123233995
#
#
#
#
#
# 62855621e-65⋅sin(θ₁) - 2.29584502165847e-49⋅sin(θ₂)⋅cos(θ₁))⋅cos(θ₇) + 1.25046
#
# 73677e-17⋅cos(θ₁))⋅cos(θ₄) - 6.12323399573677e-17⋅sin(θ₁)⋅sin(θ₂) + 3.74939945
#
#
#
#
#
# 235367338e-14⋅sin(θ₁)⋅cos(θ₂) - 102.616⋅sin(θ₁) + 204.216⋅sin(θ₂)⋅cos(θ₁)
#
# 665464e-33⋅cos(θ₁)⋅cos(θ₂) - 3.74939945665464e-33⋅cos(θ₁))⋅cos(θ₅) - 3.7493994
#
#
#
#
#
#
#
# 5665464e-33⋅sin(θ₁)⋅sin(θ₂) + 2.29584502165847e-49⋅cos(θ₁)⋅cos(θ₂) - 2.2958450
#
#
#
#
#
#
#
# 2165847e-49⋅cos(θ₁))⋅cos(θ₆) - 2.29584502165847e-49⋅sin(θ₁)⋅sin(θ₂) + 1.405799
#
#
#
#
#
#
#
# 62855621e-65⋅cos(θ₁)⋅cos(θ₂) - 1.40579962855621e-65⋅cos(θ₁))⋅cos(θ₇) + 204.216
#
#
#
#
#
#                                                                          ⎤
#                                                                          ⎥
# ⋅sin(θ₁)⋅sin(θ₂) - 1.25046235367338e-14⋅cos(θ₁)⋅cos(θ₂) + 102.616⋅cos(θ₁)⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎦
